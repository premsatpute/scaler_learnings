# %% [markdown]
# <a href="https://colab.research.google.com/github/premsatpute/scaler_learnings/blob/dev_prem/createdfromcollab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_excel("/content/FuelLid_TCD.xlsx")

# %%
df.head(5)
# Out:
#                   Label                                            Actions  \
# 0   Fuel Lid Open Alert                                                NaN
# 1  Logical Combinations                                                NaN
# 2         Preconditions  write_did VAR_CODING_MAHINDRA_BODY_FUNCTION_MO...
# 3                   TC1  SendCAN IgnMode=On; SendCAN LVSD/HVSD=Set; Sen...
# 4                   TC2  SendCAN IgnMode=On; SendCAN LVSD/HVSD=Not Set;...
#
#   Expected Results
# 0              NaN
# 1              NaN
# 2              NaN
# 3  VerifyAlert OFF
# 4  VerifyAlert OFF
